# %%
import pandas as pd

#read file
data = pd.read_csv("customer-account-overview-1.csv", sep=",")
#set Headers of dataFrame
data.columns=['SEN', 'Product', 'Organization', 'Main Contact', 'Start Date', 'End Date', 'Last Transaction Date']
#Convert the columns to absolut values (1 if column appears in row, 0 if cont)
data = pd.get_dummies(data, columns=['Product'])
#data = data.sort_values(by=['Product'])
#print(data['Product'].to_csv(index=False))

# %%
#set a tmp array with the columns found by regex
tmp=[['Admin Toolbox', (data.filter(regex=("Product_Admin Toolbox.*")).abs().sum()).sum()],    
     ['Advanced Panelboxes', (data.filter(regex=("Product_Advanced Panelboxes.*")).abs().sum()).sum()],
     ['Agile Cards', (data.filter(regex=("Product_Agile Cards.*")).abs().sum()).sum()],
     ['Announcer', (data.filter(regex=("Product_Announcer.*")).abs().sum()).sum()],
     ['Arsenale', (data.filter(regex=("Product_Arsenale.*")).abs().sum()).sum()],
     ['Automation', (data.filter(regex=("Product_Automation.*")).abs().sum()).sum()],     
     ['Backbone Issue Sync', (data.filter(regex=("Product_Backbone Issue Sync.*")).abs().sum()).sum()],
     ['Balsamiq', (data.filter(regex=("Product_Balsamiq.*")).abs().sum()).sum()],
     ['Better Commit Policy', (data.filter(regex=("Product_Better Commit Policy.*")).abs().sum()).sum()],
     ['Better Content Archiving', (data.filter(regex=("Product_Better Content Archiving.*")).abs().sum()).sum()],
     ['Better Exporter', (data.filter(regex=("Product_Better.*Exporter.*")).abs().sum()).sum()],  
     ['BigPicture', (data.filter(regex=("Product_BigPicture.*")).abs().sum()).sum()], 
     ['Bug Watcher', (data.filter(regex=("Product_Bug Watcher.*")).abs().sum()).sum()],
     ['Bulk Clone', (data.filter(regex=("Product_Bulk Clone.*")).abs().sum()).sum()],
     ['CUTE', (data.filter(regex=("Product_CUTE.*")).abs().sum()).sum()],
     ['Calendar Sync', (data.filter(regex=("Product_Calendar Sync.*")).abs().sum()).sum()],   
     ['Canned Responses', (data.filter(regex=("Product_Canned Responses.*")).abs().sum()).sum()],
     ['Cenote Lockpoint', (data.filter(regex=("Product_Cenote Lockpoint.*")).abs().sum()).sum()],
     ['Clone Plus', (data.filter(regex=("Product_Clone Plus.*")).abs().sum()).sum()],
     ['Comala', (data.filter(regex=("Product_Comala.*")).abs().sum()).sum()],
     ['ConfiForms', (data.filter(regex=("Product_ConfiForms.*")).abs().sum()).sum()],
     ['Configuration Management Toolkit', (data.filter(regex=("Product_Configuration Management Toolkit.*")).abs().sum()).sum()],
     ['Configuration Manager', (data.filter(regex=("Product_Configuration Manager.*")).abs().sum()).sum()],
     ['Content Exporter', (data.filter(regex=("Product_Content Exporter.*")).abs().sum()).sum()],
     ['Content Formatting Macros', (data.filter(regex=("Product_Content Formatting Macros.*")).abs().sum()).sum()],
     ['Copy Page Tree', (data.filter(regex=("Product_Copy Page Tree.*")).abs().sum()).sum()],
     ['Courses and Quizzes', (data.filter(regex=("Product_Courses and Quizzes.*")).abs().sum()).sum()],
     ['Create on Transition', (data.filter(regex=("Product_Create on Transition.*")).abs().sum()).sum()],
     ['Customer Satisfaction Survey', (data.filter(regex=("Product_Customer Satisfaction Survey.*")).abs().sum()).sum()],
     ['Delegated Project Creator', (data.filter(regex=("Product_Delegated Project Creator.*")).abs().sum()).sum()],
     ['draw.io', (data.filter(regex=("Product_draw.io.*")).abs().sum()).sum()],
     ['EazyBI', (data.filter(regex=("Product_eazyBI.*")).abs().sum()).sum()],    
     ['Element', (data.filter(regex=("Product_Elements.*")).abs().sum()).sum()],    
     ['Email This Issue', (data.filter(regex=("Product_Email This Issue.*")).abs().sum()).sum()],
     ['Excel-like Issue Editor', (data.filter(regex=("Product_Excel-like Issue Editor.*")).abs().sum()).sum()],
     ['Exploratory Testing', (data.filter(regex=("Product_Exploratory Testing.*")).abs().sum()).sum()],
     ['Extension for Jira Service Desk', (data.filter(regex=("Product_Extension for Jira Service Desk.*")).abs().sum()).sum()],
     ['FAQ for Confluence', (data.filter(regex=("Product_FAQ for Confluence.*")).abs().sum()).sum()],
     ['Git Integration', (data.filter(regex=("Product_Git Integration.*")).abs().sum()).sum()],
     ['GitLab Listener', (data.filter(regex=("Product_GitLab Listener.*")).abs().sum()).sum()],
     ['Glossary for Confluence', (data.filter(regex=("Product_Glossary for Confluence.*")).abs().sum()).sum()],
     ['Gliffy Diagram', (data.filter(regex=("Product_Gliffy Diagram.*")).abs().sum()).sum()],    
     ['Insight', (data.filter(regex=("Product_Insight.*")).abs().sum()).sum()],
     ['Insight Discovery', (data.filter(regex=("Product_Insight Discovery.*")).abs().sum()).sum()],
     ['Issue Publisher for Jira', (data.filter(regex=("Product_Issue Publisher for Jira.*")).abs().sum()).sum()],
     ['JEditor', (data.filter(regex=("Product_JEditor.*")).abs().sum()).sum()],
     ['JIRA Command Line Interface', (data.filter(regex=("Product_JIRA Command Line Interface.*")).abs().sum()).sum()], 
     ['Jira Misc', (data.filter(regex=("Product_Jira Misc.*")).abs().sum()).sum()],
     ['JSU', (data.filter(regex=("Product_JSU.*")).abs().sum()).sum()],
     ['Kantega', (data.filter(regex=("Product_Kantega.*")).abs().sum()).sum()],    
     ['Linchpin', (data.filter(regex=("Product_Linchpin.*")).abs().sum()).sum()],
     ['Microblogging for Confluence', (data.filter(regex=("Product_Microblogging for Confluence.*")).abs().sum()).sum()],
     ['Mobile for Jira', (data.filter(regex=("Product_Mobile for Jira.*")).abs().sum()).sum()],
     ['NPS for JIRA', (data.filter(regex=("Product_NPS for JIRA.*")).abs().sum()).sum()],
     ['Out Of Office Assistant', (data.filter(regex=("Product_Out Of Office Assistant.*")).abs().sum()).sum()],
     ['PocketQuery for Confluence', (data.filter(regex=("Product_PocketQuery for Confluence.*")).abs().sum()).sum()],
     ['Polls for Confluence', (data.filter(regex=("Product_Polls for Confluence.*")).abs().sum()).sum()],   
     ['Portfolio for Jira', (data.filter(regex=("Product_Portfolio for Jira.*")).abs().sum()).sum()],
     ['Project Specific Select Field for JIRA', (data.filter(regex=("Product_Project Specific Select Field for JIRA.*")).abs().sum()).sum()],
     ['Project Team for Jira', (data.filter(regex=("Product_Project Team for Jira.*")).abs().sum()).sum()],
     ['Questions for Confluence', (data.filter(regex=("Product_Questions for Confluence.*")).abs().sum()).sum()],   
     ['Queues for Jira Service Desk', (data.filter(regex=("Product_Queues for Jira Service Desk.*")).abs().sum()).sum()],
     ['Raley Email Notifications', (data.filter(regex=("Product_Raley Email Notifications.*")).abs().sum()).sum()],
     ['Run CLI Actions', (data.filter(regex=("Product_Run CLI Actions.*")).abs().sum()).sum()],
     ['SQL Reporter for JIRA', (data.filter(regex=("Product_SQL Reporter for JIRA.*")).abs().sum()).sum()],
     ['Scroll Exporter for Confluence', (data.filter(regex=("Product_Scroll.*Exporter for Confluence.*")).abs().sum()).sum()],
     ['Secure Login', (data.filter(regex=("Product_Secure Login.*")).abs().sum()).sum()],
     ['Smart Attachments for JIRA', (data.filter(regex=("Product_Smart Attachments for JIRA.*")).abs().sum()).sum()],    
     ['Smarter Search for Bitbucket', (data.filter(regex=("Product_Smarter Search for Bitbucket.*")).abs().sum()).sum()],
     ['TFS4JIRA', (data.filter(regex=("Product_TFS4JIRA.*")).abs().sum()).sum()],
     ['Space Hierarchy', (data.filter(regex=("Product_Space Hierarchy.*")).abs().sum()).sum()],
     ['TM4J - Test Management for Jira', (data.filter(regex=("Product_TM4J - Test Management for Jira.*")).abs().sum()).sum()],
     ['Table Filter and Charts for Confluence', (data.filter(regex=("Product_Table Filter and Charts for Confluence.*")).abs().sum()).sum()],
     ['Team Calendars for Confluence', (data.filter(regex=("Product_Team Calendars for Confluence.*")).abs().sum()).sum()],
     ['The Scheduler for JIRA', (data.filter(regex=("Product_The Scheduler for JIRA.*")).abs().sum()).sum()],
     ['Translation for Jira Service Desk', (data.filter(regex=("Product_Translation for Jira Service Desk.*")).abs().sum()).sum()],
     ['Ultimate', (data.filter(regex=("Product_Ultimate.*")).abs().sum()).sum()],  
     ['UnView for Jira', (data.filter(regex=("Product_UnView for Jira.*")).abs().sum()).sum()],
     ['Update on Transition', (data.filter(regex=("Product_Update on Transition.*")).abs().sum()).sum()],
     ['User Profiles', (data.filter(regex=("Product_User Profiles.*")).abs().sum()).sum()],
     ['WBS Gantt-Chart', (data.filter(regex=("Product_WBS Gantt-Chart.*")).abs().sum()).sum()],
     ['Werewolf for Jira', (data.filter(regex=("Product_Werewolf for Jira.*")).abs().sum()).sum()],
     ['Workflow Essentials for Jira', (data.filter(regex=("Product_Workflow Essentials for Jira.*")).abs().sum()).sum()],
     ['WorklogPRO', (data.filter(regex=("Product_WorklogPRO.*")).abs().sum()).sum()],    
     ['PowerScripts', (data.filter(regex=("Product_Power.*")).abs().sum()).sum()],
     ['ScriptRunner', (data.filter(regex=("Product_ScriptRunner.*")).abs().sum()).sum()],
     ['Structure', (data.filter(regex=("Product_Structure.*")).abs().sum()).sum()],
     ['Tempo', (data.filter(regex=("Product_Tempo.*")).abs().sum()).sum()],
     ['Toolbox', (data.filter(regex=("Product_Jira Workflow Toolbox.*")).abs().sum()).sum()],
     ['Xporter', (data.filter(regex=("Product_Xporter.*")).abs().sum()).sum()],
     ['XRay', (data.filter(regex=("Product_Xray.*")).abs().sum()).sum()],
     ['Zephyr', (data.filter(regex=("Product_Zephyr.*")).abs().sum()).sum()],
    ['Atlassian', (data.filter(regex=("(Product_Confluence|Product_Jira Software|Product_Jira Core|"+
                                      "Product_Bitbucket|Product_Atlassian Cloud|Product_Jira Service Desk|"+
                                      "Product_Bamboo|Product_Crowd|Product_Crucible|Product_Fisheye).*")).abs().sum()).sum()],
     ['Others', (data.filter(regex=(
         "Product_(?!Automation|BigPicture|draw.io|eazyBI|Elements|"+
         "Insight|Jira Misc|JSU|Kantega|Power|ScriptRunner|Structure|Tempo|Jira Workflow Toolbox|Xporter|"+
         "Xray|Zephyr|Confluence|Jira Software|Jira Core|Bitbucket|Atlassian Cloud|Jira Service Desk|Bamboo|"+
     "Admin Toolbox|Advanced Panelboxes|Agile Cards|Announcer|Arsenale|Backbone Issue Sync|Balsamiq|"+
     "Better Commit Policy|Better Content Archiving|Better.*Exporter|Crowd|Crucible|Fisheye|Bug Watcher|"+
     "Bulk Clone|CUTE|Calendar Sync|Canned Responses|Cenote Lockpoint|Clone Plus|Comala|ConfiForms|"+
     "Configuration Management Toolkit|Configuration Manager|Content Exporter|Content Formatting Macros|"+
         "Copy Page Tree|Courses and Quizzes|Create on Transition|Customer Satisfaction Survey|Delegated Project Creator"+
     "Email This Issue|Excel-like Issue Editor|Exploratory Testing|Extension for Jira Service Desk|FAQ for Confluence"+
     "Git Integration|GitLab Listener|Glossary for Confluence|Gliffy Diagram|Insight Discovery|Issue Publisher for Jira|"+
         "JEditor|JIRA Command Line Interface|Linchpin|Microblogging for Confluence|Mobile for Jira|NPS for JIRA|"+
         "Out Of Office Assistant|PocketQuery for Confluence|Polls for Confluence|Portfolio for Jira|"+
         "Project Specific Select Field for JIRA|Project Team for Jira|Questions for Confluence|Queues for Jira Service Desk|"+
     "Raley Email Notifications|SQL Reporter for JIRA|Scroll.*Exporter for Confluence|Secure Login|Smart Attachments for JIRA|"+
         "Smarter Search for Bitbucket|Space Hierarchy|TFS4JIRA|TM4J - Test Management for Jira|"+
         "Table Filter and Charts for Confluence|Team Calendars for Confluence|The Scheduler for JIRA|"+
         "Translation for Jira Service Desk|Ultimate|UnView for Jira|Update on Transition|User Profiles|WBS Gantt-Chart|"+
         "Werewolf for Jira|Workflow Essentials for Jira|WorklogPRO)"
     )).abs().sum()).sum()]]


#create a new dataframe with the tmp array
factor = pd.DataFrame(tmp, columns = ['Unternehmen', 'Absolut'])
#sort the dataframe descending by absolut value
factor = factor.sort_values(by=['Absolut'], ascending=False)

#print the rows in dataframe
print(factor)
#print the total sum
print(factor.sum())

'''print(data.filter(regex=(
         "Product_(?!Automation|BigPicture|draw.io|eazyBI|Elements|"+
         "Insight|Jira Misc|JSU|Kantega|Power|ScriptRunner|Structure|Tempo|Jira Workflow Toolbox|Xporter|"+
         "Xray|Zephyr|Confluence|Jira Software|Jira Core|Bitbucket|Atlassian Cloud|Jira Service Desk|Bamboo)"
     )))
     '''

#drop the Others row
factor = factor[factor.Unternehmen != 'Others']
#drop the Atlassian row
factor = factor[factor.Unternehmen != 'Atlassian']
# Out:
#                                Unternehmen  Absolut
# 92                               Atlassian       82
# 85                            ScriptRunner       17
# 48                                     JSU       12
# 31                                  EazyBI       11
# 88                                 Toolbox        9
# 93                                  Others        8
# 87                                   Tempo        8
# 84                            PowerScripts        8
# 49                                 Kantega        7
# 42                                 Insight        7
# 32                                 Element        7
# 30                                 draw.io        6
# 91                                  Zephyr        6
# 89                                 Xporter        6
# 47                               Jira Misc        5
# 5                               Automation        5
# 27                    Create on Transition        4
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

#Get only the first 8 rows
factor = factor.head(8)
#define the width of the bar
width = 0.35

#define the xrange
ind = np.arange(len(factor['Unternehmen']))  

#create the subplot
fig, ax = plt.subplots()

#create the bars
rects1 = ax.bar(ind - width/2, factor['Absolut'], width, color='SkyBlue')

#set the ylabel
ax.set_ylabel('Absolutwerte')
#set the title
ax.set_title('Häufigkeit der Lizenzen')
#set the position for the x labels
ax.set_xticks(ind)

#set the x labels
ax.set_xticklabels(factor.Unternehmen)
fig.set_size_inches(18.5, 10.5, forward=True)
plt.show()
